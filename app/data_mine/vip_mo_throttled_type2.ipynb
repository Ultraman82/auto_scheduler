# %%
import pandas as pd
import multiprocessing as mp
import numpy as np
# import datetime
logs = pd.read_csv("./data_nov/logs_nov.csv")
proc = pd.read_csv("./data_nov/processes_nov.csv")
orders = pd.read_csv("./data_nov/orders_nov.csv")
logs.time_out = pd.to_datetime(logs.time_out, infer_datetime_format=True)
orders.set_index('order_number', inplace=True)

# %%
vip_orders = orders[(~orders.product_length.isnull()) & (orders.order_status == 55) & orders.reference_number.str.startswith('HK') & (orders.item_description.str.contains('RAIL'))].copy()
vip_orders['y'] = 0
vip_orders['steps'] = 0
vip_mos = vip_orders.index.values.tolist()
vip_logs = logs[(logs.order_number.isin(vip_mos)) & (logs.quantity_complete != 0)].copy()
vip_logs.sort_values('sequence_code', ascending=True, inplace=True)
drop_cols = ['customer_job_number', 'reference_number', 'item_number', 'product_variant', 'product_clearance',  'product_block_count', 'product_g1', 'product_pitch',  'order_status', 'order_release_code', 'order_customer_name', 'order_replied_due', 'order_scheduled_due', 'order_original_due', 'order_scheduled_shipping_date', 'order_class', 'promise_date', 'sales_item_number', 'printed_due']
vip_orders = vip_orders.drop(columns=drop_cols)
# facility_ids = ['B0021', 'F0010', 'B0010', 'K0010', 'K0020', 'B0012', 'B0020', 'B0040', 'B0070', 'B0080', 'C0040', 'C0060', 'C0080', 'C0010','C0020', 'J0020', 'H0020', 'D0010', 'H0070', 'H0010', 'D0020','H0030', 'C0050', 'C0100', 'C0110', 'J0025', 'B0025', 'C0075','B0060', 'B0090', 'C0090', 'B0030', 'C0070', 'K0011', 'H0046','H0050', 'B0050', 'H0060', 'B0015', 'H0045', 'B0062', 'J0060','H0051', 'J0050', 'C0030', 'C0031']
# vip_orders[facility_ids] = 0
vip_orders.head()
vip_logs['time_out'] = pd.to_datetime(vip_logs['time_out'])

# %%
vip_mos = vip_orders.index.values.tolist()

# %%
THROTTLE_MIN = 2880
off_days = ['2021-09-04', '2021-09-05', '2021-09-11', '2021-09-12', '2021-09-18', '2021-09-19', '2021-09-25', '2021-09-26', '2021-10-02', '2021-10-03', '2021-10-09', '2021-10-10', '2021-10-16', '2021-10-17', '2021-10-23', '2021-10-24', '2021-10-30', '2021-10-31', '2021-11-06', '2021-11-07', '2021-11-13', '2021-11-14', '2021-11-20', '2021-11-21', '2021-11-25', '2021-11-26', '2021-11-27', '2021-11-28', '2021-12-04', '2021-12-05', '2021-12-11', '2021-12-12', '2021-12-18', '2021-12-19', '2021-12-23', '2021-12-24', '2021-12-25', '2021-12-26', '2022-01-01', '2022-01-02', '2022-01-03', '2022-01-08', '2022-01-09', '2022-01-15', '2022-01-16', '2022-01-22', '2022-01-23', '2022-01-29', '2022-01-30', '2022-02-05', '2022-02-06', '2022-02-12', '2022-02-13', '2022-02-19', '2022-02-20', '2022-02-26', '2022-02-27', '2022-03-05', '2022-03-06', '2022-03-12', '2022-03-13', '2022-03-19', '2022-03-20', '2022-03-26', '2022-03-27', '2022-04-02', '2022-04-03', '2022-04-09', '2022-04-10', '2022-04-16', '2022-04-17', '2022-04-23', '2022-04-24', '2022-04-30', '2022-05-01', '2022-05-07', '2022-05-08', '2022-05-14', '2022-05-15', '2022-05-21', '2022-05-22', '2022-05-28', '2022-05-29', '2022-05-30', '2022-06-04', '2022-06-05', '2022-06-11', '2022-06-12', '2022-06-18', '2022-06-19', '2022-06-25', '2022-06-26', '2022-07-02', '2022-07-03', '2022-07-04', '2022-07-05', '2022-07-09', '2022-07-10', '2022-07-16', '2022-07-17', '2022-07-23', '2022-07-24', '2022-07-30', '2022-07-31', '2022-08-06', '2022-08-07', '2022-08-13', '2022-08-14', '2022-08-20', '2022-08-21', '2022-08-27', '2022-08-28', '2022-09-03', '2022-09-04', '2022-09-05', '2022-09-10', '2022-09-11', '2022-09-17', '2022-09-18', '2022-09-24', '2022-09-25', '2022-10-01', '2022-10-02', '2022-10-08', '2022-10-09', '2022-10-15', '2022-10-16', '2022-10-22', '2022-10-23', '2022-10-29', '2022-10-30', '2022-11-05', '2022-11-06']
o_days = pd.to_datetime(off_days, infer_datetime_format=True, utc=True)
def cal_days (row):
    return len(list(x for x in o_days if (row.start < x < row.time_out)))

def f(mo):       
    mo_logs = vip_logs[vip_logs.order_number == mo].sort_values('sequence_code')    
    mo_logs = mo_logs.drop_duplicates(subset=['sequence_code'], keep='first')    
    mo_logs = mo_logs.drop_duplicates(subset=['facility_id'], keep='first')    
    mo_logs['start'] = mo_logs['time_out'].shift(1)
    mo_logs['diff'] = mo_logs['time_out'].diff(periods=1).astype('timedelta64[m]')                
    mo_logs['wcount'] = 0
    mo_logs['diff2'] = 0
    
    if len(mo_logs[mo_logs['diff'] < 0]):
        print('negative', mo)
        return
    try:            
        # mo_logs['w_count'] = mologs.applylen(list(x for x in o_days if (mo_logs['start'] < x < mo_logs.time_out)))
        # for index, row in mo_logs.iterrows():
        #     mo_logs[index, 'wcount'] = len(list(x for x in o_days if (row['start'] < x < row['time_out'])))        
        for r in mo_logs.itertuples():
            mo_logs.loc[r[0], 'wcount'] = len(list(x for x in o_days if (r.start < x < r.time_out)))        
        mo_logs['diff2'] = mo_logs['diff'] - mo_logs['wcount'] * 1440
        # mo_logs['diff2'] = np.where(mo_logs['diff2'] > THROTTLE_MIN, THROTTLE_MIN, mo_logs['diff2'])
        mo_logs.loc[(mo_logs['diff2'] > THROTTLE_MIN) and (mo_logs['facility_id'] != 'H0030'), 'diff2'] = THROTTLE_MIN        
        period = mo_logs['diff2'].sum() / 60
        durations_on_facilities = mo_logs.pivot(index='order_number', columns='facility_id', values='diff2')
        return mo, durations_on_facilities, period, len(mo_logs) 
    except Exception as e: print(mo, e)

def append_res(result):        
    for i in result:
        if i:
            mo, series, period, steps = i
            try:                                
                for f in series.columns:
                    vip_orders.loc[mo, f] = series.loc[mo, f]
                vip_orders.loc[mo, 'y'] = period
                vip_orders.loc[mo, 'steps'] = steps
            except Exception as e: print(e)

if __name__ == "__main__":        
    with mp.Pool(16) as pool:        
        print('pool started')
        results = pool.map_async(f, vip_mos, callback = append_res)
        results.wait() 
print("done")
vip_orders.describe()
# Out:
# M860258 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().M896613
# M923814  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().M905099
#
# M863662 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all(). M879548The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all(). M890976
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().M050357 M888098M913338
# M893380M919178
#   M909360The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all
The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M861923 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M905675M925769  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M887850 M892122The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M068977 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M923698 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M844208M883664 M901717  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M925776
#
#  M884612The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().M937136
#   The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M921979M874824 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().M871254
#   The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# M895115 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M947301M905676  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M885289 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().M892123
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().M913003
#  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M901867 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M844209M781879  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# M901718M904211M941129   The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().M941090
#  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# M921984 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M927119M871255 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all(). M902009
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M883947 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M898348 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().M886233 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# M941185M941128  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# M868925 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().M944379
#  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().M897838
#  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M040924M911795M872557  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# M957270  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M890270 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# M927120M881380  M913914The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M937914 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M898352M887970  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# M913339 M944229The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M908272 M880931M939617 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# M908829M923952 M927990 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all(). The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().M893448
# M872558The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M927121M879199  M920223The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M917496 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M888099 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M944316M927815 M913319 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all(). The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# M868926M939619 M883681The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all(). The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all(). The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
#
# M045324 M883706 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# M950882M947990 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all(). The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# M872559 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().M901670M879200M867192
#  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all(). The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M947925
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M860236 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M953370 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M043871 M913323M920809  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().M883682
# M927634The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all(). M883710
#  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all(). The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# M879515The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().M916986
#
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M883756 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M866095M901671  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M872560
#  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M879201 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().M852628
#  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M895501 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M953371 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M920102 M968653The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M883711M883683The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().M889437M868927
#   The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M915210M063428  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().M883757The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M920231M872561M893286  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all(). The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
#
# M879202 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M931245 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M860238 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M920041 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# ...
# M882215The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all(). The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
#  M914525
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().M880518M902464
#  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all(). The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# M883631
#  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M045357 M907399The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M907624 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M935820 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M912330M916743  M908373M863693 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all(). M886314 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
#
# M883366M914526M872272M871825   The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M899112
#  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# M898514The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M940914 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M909404 M027458The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M907400 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M884115 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M859012M863694 M901680 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all(). M910014
# M883371The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all(). M912331
#  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M935504 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().M871826
#  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().M061206
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# M872273M898515  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().M872852
#  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M895979 M931003The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all(). The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# M907401 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().M893822
#  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M961677M884163  M932116The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all(). The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M863695
#
#  M879540 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M886616M899310M912332  M871827The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M886733M963791 M874617  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M895980 M888109The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().M907402M893823  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
#
# M961678 M885290M932117The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all(). M901681
#  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#  M871829The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().M925071M937913
# M912333   The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M899500 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M872856M894685  M963792The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M907403M893825 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().M903631
# M859777  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# M961679M932118 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M885292The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M872417M892061M052851M883501   The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all(). The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M863696
#
#  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M899511 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M886734M882050M894611 M935826   The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
#
# M907447
#  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M895981 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M888110M000026M901683M929944 M901719M016458  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all(). M886520 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().M872418The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
#  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().M883510The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().M923704
#  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M893839
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M894612 M895982M889406The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().M882063
# M880819
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M907500M000027M889336
#     The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().M889431M915199M888111The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all(). The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
#
#
#   M892062The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M871857The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all(). The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# M894613 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M863697M872424M889407  M894052M914592  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all(). The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
#
# M872237 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M891958M907501 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all(). M880505The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# M889433The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M040064M888112  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M049527 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M894614 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M892063 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M930107M871860 M872450 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().M894055M914593
#  The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
#
# The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M889408 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# M872238 The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/edgar/miner/vip_mo_throttled_type2.ipynb Cell 4 in <cell line: 44>()
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/edgar/miner/vip_mo_throttled_type2.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=45'>46</a>         print('pool started')
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/edgar/miner/vip_mo_throttled_type2.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=46'>47</a>         results = pool.map_async(f, vip_mos, callback = append_res)
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/edgar/miner/vip_mo_throttled_type2.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=47'>48</a>         results.wait()
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/edgar/miner/vip_mo_throttled_type2.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=48'>49</a> print("done")
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/edgar/miner/vip_mo_throttled_type2.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=49'>50</a> vip_orders.describe()
#
# File ~/miniconda3/lib/python3.9/multiprocessing/pool.py:762, in ApplyResult.wait(self, timeout)
#     761 def wait(self, timeout=None):
# --> 762     self._event.wait(timeout)
#
# File ~/miniconda3/lib/python3.9/threading.py:581, in Event.wait(self, timeout)
#     579 signaled = self._flag
#     580 if not signaled:
# --> 581     signaled = self._cond.wait(timeout)
#     582 return signaled
#
# File ~/miniconda3/lib/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:

# %%
vip_backup = vip_orders.copy()
vip_orders.to_csv('vip_weekend.csv')

# %%
def adjust_time(r):
    if r > 504:
        return 504
    elif r < 24:
        return 24
    else:
        return r
vip_orders['y'] = vip_orders['y'].apply(adjust_time)
vip_orders[vip_orders['y'] > 504]
# Out:
# Empty DataFrame
# Columns: [item_description, product_family, product_model, product_length, order_quantity, y, steps, D0010, D0020, F0010, C0010, C0020, C0060, C0080, C0090, K0010, K0020, C0075, C0070, C0100, C0110, J0020, C0120, H0010, H0020, H0030, H0070, J0050, J0060, B0010, B0012, B0020, B0021, B0040, B0070, B0080, B0060, C0040, K0011, C0050, C0030, C0031, C0035, H0046, GL010, GL130, GL140, B0050, H0045, H0060, H0050, B0030, F0020, J0025, B0015, GL030, H0051, 0010, B0025]
# Index: []
#
# [0 rows x 59 columns]

# %%
vip_orders.describe()
# Out:
#        product_length  order_quantity             y         steps  D0010  \
# count    39034.000000    39034.000000  39034.000000  39034.000000    0.0
# mean      1186.267492        8.259236     99.023408      6.079290    NaN
# std       1384.598633        5.433348     62.191813      2.612124    NaN
# min         38.000000        1.000000     24.000000      0.000000    NaN
# 25%        318.000000        4.000000     56.700000      4.000000    NaN
# 50%        670.000000        8.000000     85.716667      6.000000    NaN
# 75%       1600.000000       10.000000    124.000000      8.000000    NaN
# max      56290.000000       50.000000    434.483333     17.000000    NaN
#
#               D0020        F0010   C0010         C0020         C0060  ...  \
# count  11950.000000  37923.00000     1.0  22351.000000  16031.000000  ...
# mean    1970.923180    900.91256  1525.0   1101.235873   1382.599651  ...
# std      964.604725    890.48446     NaN    804.388889   1049.881818  ...
# min     -588.000000  -1059.00000  1525.0  -1335.000000  -1185.000000  ...
# 25%     1310.250000    120.00000  1525.0    560.000000    496.000000  ...
# 50%     2128.000000    735.00000  1525.0    933.000000   1202.000000  ...
# 75%     2880.000000   1313.00000  1525.0   1469.000000   2450.000000  ...
# max     2880.000000   2880.00000  1525.0   2880.000000   2880.000000  ...
#
#              H0060   H0050        B0030   F0020   J0025        B0015  \
# count    44.000000    26.0     7.000000     1.0     1.0    66.000000
# mean   2815.977273  2880.0  2508.000000  1002.0  2701.0  2655.318182
# std     424.678729     0.0   984.219488     NaN     NaN   469.310531
# min      63.000000  2880.0   276.000000  1002.0  2701.0     0.000000
# 25%    2880.000000  2880.0  2880.000000  1002.0  2701.0  2567.250000
# 50%    2880.000000  2880.0  2880.000000  1002.0  2701.0  2876.000000
# 75%    2880.000000  2880.0  2880.000000  1002.0  2701.0  2880.000000
# max    2880.000000  2880.0  2880.000000  1002.0  2701.0  2880.000000
#
#              GL030   H0051  0010        B0025
# count     5.000000     7.0   0.0    10.000000
# mean   2286.400000  2880.0   NaN   845.400000
# std    1046.862598     0.0   NaN   133.799352
# min     463.000000  2880.0   NaN   648.000000
# 25%    2329.000000  2880.0   NaN   768.500000
# 50%    2880.000000  2880.0   NaN   841.500000
# 75%    2880.000000  2880.0   NaN   925.750000
# max    2880.000000  2880.0   NaN  1050.000000
#
# [8 rows x 56 columns]

# %%
b_types = ['-III', '(GK)', '(GP)', '-II']
p_types = ['K','E','P','F','T','S','M','H']
des = vip_orders['item_description']
# vip_orders.loc[vip_orders.y < 8, 'y'] = 8

# %%
test = vip_orders.copy()
test['ZLE'] = np.where(test['item_description'].str.count('LE'), 1, 0)
test['ZGK'] = np.where(test['item_description'].str.count('GK'), 1, 0)
test['ZLT'] = np.where(test['item_description'].str.count('LT'), 1, 0)
test['ZGP'] = np.where(test['item_description'].str.count('GP'), 1, 0)
test['FULL'] = np.where(test['product_model'].str.contains('55|65'), 1, 0)
# cols_a = ['B0012', 'B0015', 'B0021', 'B0025', 'B0030', 'B0040', 'B0050', 'B0060', 'B0062', 'B0070', 'B0080', 'C0020', 'C0030', 'C0031', 'C0035', 'C0040', 'C0050', 'C0060', 'C0070', 'C0075', 'C0080', 'C0090', 'C0100', 'C0110', 'C0120', 'D0010', 'D0020', 'F0010', 'F0020', 'GL010', 'GL030', 'GL130', 'GL140', 'H0010', 'H0020', 'H0030', 'H0045', 'H0046', 'H0050', 'H0051', 'H0060', 'H0070', 'J0020', 'J0025', 'J0050', 'J0060', 'K0010', 'K0011', 'K0020', 'ZGK', 'ZGP', 'ZLE', 'ZLT', ]
cols_b = ['B0012', 'B0015', 'B0021', 'B0025', 'B0030', 'B0040', 'B0050', 'B0060', 'B0070', 'B0080', 'C0020', 'C0030', 'C0031', 'C0035', 'C0040', 'C0050', 'C0060', 'C0070', 'C0075', 'C0080', 'C0090', 'C0100', 'C0110', 'C0120', 'D0010', 'D0020', 'F0010', 'F0020', 'GL010', 'GL030', 'GL130', 'GL140', 'H0010', 'H0020', 'H0030', 'H0045', 'H0046', 'H0050', 'H0051', 'H0060', 'H0070', 'J0020', 'J0025', 'J0050', 'J0060', 'K0010', 'K0011', 'K0020', 'ZGK', 'ZGP', 'ZLE', 'ZLT', 'FULL', 'order_quantity', 'product_family', 'product_length', 'product_model', 'steps', 'y']
# cols_b = ['ZGK', 'ZGP', 'ZLE', 'ZLT', 'order_quantity', 'product_family', 'product_length', 'product_model', 'steps', 'y']
# cols_a = ['B0012', 'B0015', 'B0021', 'B0025', 'B0030', 'B0040', 'B0050', 'B0060', 'B0070', 'B0080', 'C0020', 'C0030', 'C0031', 'C0035', 'C0040', 'C0050', 'C0060', 'C0070', 'C0075', 'C0080', 'C0090', 'C0100', 'C0110', 'C0120', 'D0010', 'D0020', 'F0010', 'F0020', 'GL010', 'GL030', 'GL130', 'GL140', 'H0010', 'H0020', 'H0030', 'H0045', 'H0046', 'H0050', 'H0051', 'H0060', 'H0070', 'J0020', 'J0025', 'J0050', 'J0060', 'K0010', 'K0011', 'K0020', 'ZGK', 'ZGP', 'ZLE', 'ZLT', ]
cols_a = ['B0012', 'B0015', 'B0021', 'B0025', 'B0030', 'B0040', 'B0050', 'B0060', 'B0070', 'B0080', 'C0020', 'C0030', 'C0031', 'C0035', 'C0040', 'C0050', 'C0060', 'C0070', 'C0075', 'C0080', 'C0090', 'C0100', 'C0110', 'C0120', 'D0010', 'D0020', 'F0010', 'F0020', 'GL010', 'GL030', 'GL130', 'GL140', 'H0010', 'H0020', 'H0030', 'H0045', 'H0046', 'H0050', 'H0051', 'H0060', 'H0070', 'J0020', 'J0025', 'J0050', 'J0060', 'K0010', 'K0011', 'K0020']
for i in cols_a:
    test[i] = np.where(test[i].isnull(), 0, 1)

# cols_c = ['ZGK', 'ZGP', 'ZLE', 'ZLT', 'order_quantity', 'product_family', 'product_length', 'product_model', 'steps', 'y']
test = test[cols_b]
test['product_length'] = test['product_length'] / 1000
# print(len(test.columns))
dimension = len(test.columns) - 1
dimension
# Out:
# 58

# %%
test[test['FULL'] == 1]
dimension
# Out:
# 58

# %%
list_classify = ["product_family", "product_model"]
for i in list_classify:    
    test[i], uniques = pd.factorize(test[i], sort=True)
    print(uniques)
classfied = test[test.product_family.isin(range(0, 9))]
pivot = int(len(classfied) * .2)
shuffled = classfied.sample(frac=1)
train = shuffled.iloc[pivot:].copy()
val = shuffled.iloc[:pivot].copy()
train = train.astype(float)
val = val.astype(float)
train.to_csv('train_throttled_80_mo_24h.csv')
val.to_csv('val_throttled_80_mo_24h.csv')
# Out:
# Index(['HCR', 'HDR', 'HRW', 'HSR', 'SHS', 'SHW', 'SR', 'SRS', 'SRS-W'], dtype='object')
# Index(['12', '15', '15/300R', '17', '20', '21', '25', '27', '30', '35', '45',
#        '45/800R', '55', '65', '9', '9X'],
#       dtype='object')

# %%
import torch
import numpy as np
import pandas as pd
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F

class MyDataset(Dataset): 
  def __init__(self,data):     
    super(MyDataset).__init__()
    x=data.iloc[:,0:dimension].values
    y=data.iloc[:,dimension].values     
    self.x_train=torch.tensor(x,dtype=torch.float32).cuda()    
    self.y_train=torch.tensor(y,dtype=torch.float32).view(-1, 1).cuda()    
 
  def __len__(self):
    return len(self.y_train)   
  def __getitem__(self,idx):
    return self.x_train[idx],self.y_train[idx]

train_set=MyDataset(train)
val_set=MyDataset(val)
train_dl=DataLoader(train_set, batch_size=256, shuffle=True, num_workers=0)
val_dl=DataLoader(val_set, batch_size=len(val_set))

# %%
loss_fn = F.mse_loss
def fit(num_epochs, model, loss_fn, opt):
    val_best  = 26
    for epoch in range(num_epochs):        
        for xb,yb in train_dl:            
            pred = model(xb)
            loss = loss_fn(pred, yb)
            loss.backward()
            opt.step()
            opt.zero_grad()
        if epoch % 50 == 0:
            loss_val = loss.item()
            print(loss_val, epoch)            
            for v_xb,v_yb in val_dl:
                result = model(v_xb)     
                val_err = torch.mean(abs(v_yb - result) / v_yb).item() * 100                    
                print("val_err: ", val_err)
            if val_err < val_best:
                val_best = val_err
                torch.save(model.state_dict(), f"throttle_{str(val_err).replace('.', '_')[:5]}.pth")
    
class SimpleNet(nn.Module):    
    def __init__(self):
        super().__init__()
        self.linear1 = nn.Linear(dimension, 256)
        self.linear2 = nn.Linear(256, 128)        
        self.linear3 = nn.Linear(128, 64)
        self.linear4 = nn.Linear(64, 1)
        
        self.act1 = nn.ReLU() # Activation function        
        self.act2 = nn.ReLU() # Activation function
        self.act3 = nn.ReLU() # Activation function
            
    # Perform the computation
    def forward(self, x):                
        x = self.linear1(x)
        x = self.act1(x)
        x = self.linear2(x)
        x = self.act2(x)
        x = self.linear3(x)        
        x = self.act3(x)
        x = self.linear4(x)        
        return x

model = SimpleNet().cuda()
opt = torch.optim.SGD(model.parameters(), 1e-6, momentum=0.9)
fit(1000, model, loss_fn, opt)
# Out:
# 11238.400390625 0
# val_err:  80.32059073448181
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/edgar/miner/vip_mo_throttled_type2.ipynb Cell 14 in <cell line: 47>()
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/edgar/miner/vip_mo_throttled_type2.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=44'>45</a> model = SimpleNet().cuda()
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/edgar/miner/vip_mo_throttled_type2.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=45'>46</a> opt = torch.optim.SGD(model.parameters(), 1e-6, momentum=0.9)
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/edgar/miner/vip_mo_throttled_type2.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=46'>47</a> fit(1000, model, loss_fn, opt)
#
# /home/edgar/miner/vip_mo_throttled_type2.ipynb Cell 14 in fit(num_epochs, model, loss_fn, opt)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/edgar/miner/vip_mo_throttled_type2.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> pred = model(xb)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/edgar/miner/vip_mo_throttled_type2.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> loss = loss_fn(pred, yb)
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/edgar/miner/vip_mo_throttled_type2.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> loss.backward()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/edgar/miner/vip_mo_throttled_type2.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> opt.step()
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/edgar/miner/vip_mo_throttled_type2.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> opt.zero_grad()
#
# File ~/miniconda3/lib/python3.9/site-packages/torch/_tensor.py:396, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     387 if has_torch_function_unary(self):
#     388     return handle_torch_function(
#     389         Tensor.backward,
#     390         (self,),
#    (...)
#     394         create_graph=create_graph,
#     395         inputs=inputs)
# --> 396 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File ~/miniconda3/lib/python3.9/site-packages/torch/autograd/__init__.py:173, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     168     retain_graph = create_graph
#     170 # The reason we repeat same the comment below is that
#     171 # some Python versions print out the first line of a multi-line function
#     172 # calls in the traceback and some print out the last line
# --> 173 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
10-23', '2022-10-29', '2022-10-30', '2022-11-05', '2022-11-06', '2022/01/01', '2022/01/02', '2022/01/03', '2022/01/08', '2022/01/09', '2022/01/16', '2022/01/22', '2022/01/23', '2022/01/30', '2022/02/04', '2022/02/05', '2022/02/06', '2022/02/13', '2022/02/19', '2022/02/20', '2022/02/27', '2022/03/05', '2022/03/06', '2022/03/12', '2022/03/13', '2022/03/19', '2022/03/20', '2022/03/27', '2022/04/02', '2022/04/03', '2022/04/10', '2022/04/15', '2022/04/16', '2022/04/17', '2022/04/23', '2022/04/24', '2022/04/30', '2022/05/01', '2022/05/08', '2022/05/14', '2022/05/15', '2022/05/22', '2022/05/28', '2022/05/29', '2022/05/30', '2022/06/05', '2022/06/11', '2022/06/12', '2022/06/18', '2022/06/19', '2022/06/25', '2022/06/26', '2022/06/30', '2022/07/02', '2022/07/03', '2022/07/04', '2022/07/05', '2022/07/10', '2022/07/16', '2022/07/17', '2022/07/23', '2022/07/24', '2022/07/30', '2022/07/31', '2022/08/06', '2022/08/07', '2022/08/13', '2022/08/14', '2022/08/20', '2022/08/21', '2022/08/27', '2022/08/28', '2022/09/03', '2022/09/04', '2022/09/05', '2022/09/10', '2022/09/11', '2022/09/17', '2022/09/18', '2022/09/24', '2022/09/25', '2022/10/01', '2022/10/02', '2022/10/08', '2022/10/09', '2022/10/15', '2022/10/16', '2022/10/22', '2022/10/23', '2022/10/29', '2022/10/30', '2022/11/05', '2022/11/06']
# def f(mo):       
#     mo_logs = vip_logs[vip_logs.order_number == mo].copy()
#     mo_logs = mo_logs.drop_duplicates(subset=['sequence_code'], keep='first')
#     mo_logs['diff'] = mo_logs['time_out'].diff(periods=1).astype('timedelta64[m]')
#     mo_logs['start'] = mo_logs['time_out'].shift(1)    
#     mo_logs.loc[mo_logs['diff'] > THROTTLE_MIN, 'diff'] = THROTTLE_MIN
#     try:
#         # for index, row in mo_logs.iloc[1:].iterrows():                
#         #     if row['diff'] > THROTTLE_MIN:
#         #         end = row.time_out.strftime("%Y-%m-%d")
#         #         start = row.start.strftime("%Y-%m-%d")
#         #         offday_count = len(list(x for x in low_days if start < x < end))             
#         #         row['diff'] -= offday_count * 1440
#         #         if row['diff'] > THROTTLE_MIN:
#         #             # print(index)
#         #             mo_logs.loc[index, 'diff'] = THROTTLE_MIN    
#         period = mo_logs['diff'].sum() / 60
#         # return mo, period, mo_logs.iloc[0]['time_out']
#         return mo, period, len(mo_logs)
#     except Exception as e: print(mo, e)

# b_types = ['-III', '(GK)', '(GP)', '-II']
# p_types = ['K','E','P','F','T','S','M','H']
# for i in b_types:
#     vip_orders[i] = 0
# for i in p_types:
#     vip_orders[i] = 0
# vip_orders['custom'] = 0
# for index, row in vip_orders.iterrows():
#     try:
#         des = row['item_description'].split(' RAIL')[0].split('L')[1]
#         for bt in b_types:
#             if bt in des:
#                 vip_orders.loc[index, bt] = 1
#                 des = des.replace(bt, '')
#         print(des)
#         for pt in p_types:
#             if pt in des:            
#                 vip_orders.loc[index, pt] = 1
#     except Exception as e:
#         vip_orders.loc[index, 'custom'] = 1
