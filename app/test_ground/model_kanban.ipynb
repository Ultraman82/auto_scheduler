# %%
import os
import pandas as pd
import numpy as np
from datetime import timedelta, date, datetime
import difflib
import json
import torch
import torch.nn as nn
# from ml_model import cols, family_mapper, model_mapper, dev, model
from queries import kanban_storage, proc, update_processing, get_kanban, get_batch, set_kanban, stock, stock_all, demand_all, demand
from util_func import ProcessingStorage, StockStorage
set_kanban()
# Out:
# set_kanban

# %%
class SimpleNet(nn.Module):
    def __init__(self, dimension):
        super().__init__()
        self.linear1 = nn.Linear(dimension, 256)
        self.linear2 = nn.Linear(256, 128)
        self.linear3 = nn.Linear(128, 64)
        self.linear4 = nn.Linear(64, 1)

        self.act1 = nn.ReLU()  # Activation function
        self.act2 = nn.ReLU()  # Activation function
        self.act3 = nn.ReLU()  # Activation function

    # Perform the computation
    def forward(self, x):
        x = self.linear1(x)
        x = self.act1(x)
        x = self.linear2(x)
        x = self.act2(x)
        x = self.linear3(x)
        x = self.act3(x)
        x = self.linear4(x)
        return x
ALL_ML_MODEL_PATH = './ml/ALL_26_13.pth'
dimension = 59
dev = torch.device(
    "cuda") if torch.cuda.is_available() else torch.device("cpu")

model = SimpleNet(dimension).to(dev)
if torch.cuda.is_available():
    model.load_state_dict(torch.load(ALL_ML_MODEL_PATH))
else:
    model.load_state_dict(torch.load(
        ALL_ML_MODEL_PATH, map_location=torch.device('cpu')))

# %%
# proc = ProcessingStorage()
# proc.
# dimension = 59
# ALL_ML_MODEL_PATH = 'ALL_26_13.pth'
FAMILY = ['    SR', 'HCR', 'HDR', 'HRW',
          'HSR', 'SHS', 'SHW', 'SR', 'SRS', 'SRS-W']
MODEL = ['12', '12W', '15', '15/300R', '15W', '17', '20', '21',
         '25', '27', '30', '35', '45', '45/800R', '55', '65', '9', '9X']
REFRENCE = ['GY3', 'GY4', 'GYHAAS', 'HK']
facilities = ['B0012', 'B0015', 'B0021', 'B0025', 'B0030', 'B0040', 'B0050', 'B0060', 'B0070', 'B0080', 'C0020', 'C0030', 'C0031', 'C0035', 'C0040', 'C0050', 'C0060', 'C0070', 'C0075', 'C0080', 'C0090', 'C0100', 'C0110', 'C0120', 'D0010', 'D0020', 'F0010', 'F0020', 'GL010', 'GL030', 'GL130', 'GL140', 'H0010', 'H0020', 'H0030', 'H0045', 'H0046', 'H0050', 'H0051', 'H0060', 'H0070', 'J0020', 'J0025', 'J0050', 'J0060', 'K0010', 'K0011', 'K0020']
cols_to_keep = ['B0012', 'B0015', 'B0021', 'B0025', 'B0030', 'B0040', 'B0050', 'B0060', 'B0070', 'B0080', 'C0020', 'C0030', 'C0031', 'C0035', 'C0040', 'C0050', 'C0060', 'C0070', 'C0075', 'C0080', 'C0090', 'C0100', 'C0110', 'C0120', 'D0010', 'D0020', 'F0010', 'F0020', 'GL010', 'GL030', 'GL130', 'GL140', 'H0010', 'H0020', 'H0030', 'H0045', 'H0046', 'H0050', 'H0051', 'H0060', 'H0070', 'J0020', 'J0025', 'J0050', 'J0060', 'K0010', 'K0011', 'K0020', 'GK', 'GP', 'LE', 'LT', 'FULL', 'order_quantity', 'product_family', 'product_length', 'product_model', 'reference_number', 'steps']
flag_list = ['GK', 'GP', 'LE', 'LT']

family_map = {}
for i, v in enumerate(FAMILY):
    family_map[v] = i
model_map = {}
for i, v in enumerate(MODEL):
    model_map[v] = i
reference_map = {}
for i, v in enumerate(REFRENCE):
    reference_map[v] = i
def family_mapper(x):
    try:
        return family_map[x]
    except Exception as e:
        print("family:", x, e)
def model_mapper(x):
    try:
        return model_map[x]
    except Exception as e:
        print("model", x, e)


def reference_mapper(x):
    try:
        if x.startswith('HK'): return reference_map['HK']
        else:
            return reference_map[x]
    except Exception as e:
        print("reference_number", x, e)
def all_priority_call_test():
    run_id, batch_order, batch_df = get_batch()
    response = calc_priority(batch_order)
    response.set_index("batch_id", inplace=True)
    result = pd.concat([response, batch_df], axis=1, join='outer')
    result = result.reset_index()
    return result.to_json(orient="records")


def calc_priority(batch_order):
    if proc.empty:
        update_processing()
    gy_processing = proc.BACK_PROCESS.copy()
    gy_processing.drop(columns=['order_scheduled_due'], inplace=True)
    gy_prediction = partial_predict_backprocess(gy_processing)
    hk_prediction = partial_predict_hk(proc.HK.copy())

    
    kanban_df = get_kanban()
    kanban_df = kanban_df.set_index('des')
    has_start_due = kanban_df[kanban_df.start_due.notna()]
    has_start_due_list = has_start_due.index.to_list()
    for row in gy_prediction.itertuples():
        des = row.item_description
        if row.item_description in has_start_due_list:
            gy_prediction.loc[row[0],
                              'start_due'] = has_start_due.loc[des].start_due - row.pred

    gy_mos = gy_prediction.index.to_list()
    hk_mos = hk_prediction.index.to_list()

    # mathcing HK mos and batch_id
    for row in batch_order.itertuples():
        index = row[0]
        if index in hk_mos:
            batch_order.loc[index,
                            "start_due"] = hk_prediction.loc[index]['start_due']
    # mathcing GY3 mos and batch_id
    empty_batch_order = batch_order[batch_order['start_due'].isna()]
    for row in empty_batch_order.itertuples():
        index = row[0]
        if index in gy_mos:
            batch_order.loc[index,
                            "start_due"] = gy_prediction.loc[index]['start_due']
    batch_order = batch_order[batch_order['start_due'].notna()]
    batch_order = batch_order.sort_values(by='start_due')
    batch_order = batch_order.drop_duplicates('batch_id')
    batch_order = batch_order.reset_index().reset_index()
    batch_order = batch_order.rename(columns={"index": "priority"})
    batch_order['priority'] = batch_order['priority'].apply(np.int64)
    return batch_order

# %%
def partial_predict_backprocess(df):    
    df.set_index('order_number', inplace=True)
    res = df.copy()    
    with open('./etc/stage_mapper3.json') as json_file:
        stage_mapper = json.load(json_file)
        facility_index = np.array(stage_mapper["index"])
        facility_map = stage_mapper["map"]
        for row in res.itertuples():
            index = row[0]
            facility_id = row.facility_id
            facilities = np.array(row.facility.split(' '))
            cur_facility_index = np.where(facilities == facility_id)[0][0]
            mask = np.isin(facility_index, facilities)
            f_key = str(np.where(mask == True)[0])
            if cur_facility_index == 1:
                df.loc[index, 'ratio'] = 1
            else:
                ratio_arr = None
                if f_key in facility_map.keys():
                    ratio_arr = facility_map[f_key]
                else:
                    sub_key = difflib.get_close_matches(
                        f_key, facility_map.keys())[0]
                    ratio_arr = facility_map[sub_key]
                df.loc[index, 'ratio'] = sum(
                    ratio_arr[cur_facility_index - 1:])
            for f in facilities:
                res.loc[index, f] = 1
    for name in flag_list:
        res[name] = np.where(res['item_description'].str.count(name), 1, 0)
    res['FULL'] = False
    res['product_family'] = res['product_family'].apply(
        lambda x: family_mapper(x))
    res['product_model'] = res['product_model'].apply(
        lambda x: model_mapper(x))
    res['reference_number'] = res['reference_number'].apply(
        lambda x: reference_mapper(x))
    res['product_length'] = res['product_length'].apply(lambda x: x / 1000)
    res['steps'] = res['facility'].apply(lambda x: len(x.split(' ')))
    res = res.reindex(set(res.columns.tolist() + cols_to_keep), axis=1)  # version > 0.20.0
    res = res[cols_to_keep]
    res = res.fillna(0)
    val = res.astype(float)
    x = val.iloc[:, :].values
    v_xb = torch.tensor(x, dtype=torch.float32).to(dev)
    pred = model(v_xb)[:, 0].tolist()
    df['original_pred'] = pred / 24
    df['pred'] = pred * df['ratio']
    df['pred'] = df['pred'].astype('int')
    df['pred'] = df['pred'].apply(lambda x: timedelta(hours=x))
    df = df.drop_duplicates(
        subset=['item_description'], keep='first')
    df.sort_values(by='pred', ascending=False,  inplace=True)
    df.to_csv('backprocess_test.csv')
    return df


def partial_predict_hk(df):    
    df.set_index('order_number', inplace=True)
    schduled_due_exist = df[df.order_scheduled_due.notna()]
    df.printed_due = schduled_due_exist.order_scheduled_due
    df.printed_due = pd.to_datetime(df.printed_due)
    df['shipping_process_ahead'] = False
    res = df.copy()

    with open('./etc/stage_mapper3.json') as json_file:
        stage_mapper = json.load(json_file)
        facility_index = np.array(stage_mapper["index"])
        facility_map = stage_mapper["map"]
        for row in res.itertuples():
            index = row[0]
            facility_id = row.facility_id
            facilities = np.array(row.facility.split(' '))
            cur_facility_index = np.where(facilities == facility_id)[0][0]
            mask = np.isin(facility_index, facilities)
            f_key = str(np.where(mask == True)[0])
            if ('H0030' in facilities) and (facility_id < 'H0070'):
                df.loc[index, 'shipping_process_ahead'] = True
            if cur_facility_index == 1:
                df.loc[index, 'ratio'] = 1
            else:
                ratio_arr = None
                if f_key in facility_map.keys():
                    ratio_arr = facility_map[f_key]
                else:
                    sub_key = difflib.get_close_matches(
                        f_key, facility_map.keys())[0]
                    ratio_arr = facility_map[sub_key]
                df.loc[index, 'ratio'] = sum(
                    ratio_arr[cur_facility_index - 1:])
            for f in facilities:
                res.loc[index, f] = 1
    for name in flag_list:
        res[name] = np.where(res['item_description'].str.count(name), 1, 0)
    res['product_family'] = res['product_family'].apply(
        lambda x: family_mapper(x))
    res['product_model'] = res['product_model'].apply(
        lambda x: model_mapper(x))
    res['reference_number'] = res['reference_number'].apply(
        lambda x: reference_mapper(x))
    res['product_length'] = res['product_length'].apply(lambda x: x / 1000)
    res['steps'] = res['facility'].apply(lambda x: len(x.split(' ')))
    res = res.reindex(set(res.columns.tolist() + cols_to_keep),
                      axis=1)  # version > 0.20.0
    res = res[cols_to_keep]
    res = res.fillna(0)
    val = res.astype(float)
    x = val.iloc[:, :].values
    v_xb = torch.tensor(x, dtype=torch.float32).to(dev)
    pred = model(v_xb)[:, 0].tolist()
    df['original_pred'] = pred / 24
    df['pred'] = pred * df['ratio']
    df['pred'] = df['pred'].astype('int')
    df['pred'] = df['pred'].apply(
        lambda x: timedelta(hours=x))
    df.loc[df['shipping_process_ahead'], 'pred'] = df['pred'] + timedelta(days=21)
    df['start_due'] = df['printed_due'] - df['pred']
    df.sort_values('start_due', inplace=True)
    df.to_csv('hk.csv')
    return df

all_priority_call_test()

# %%
GY4_RAILS = ['SRS12', 'SRS12W', 'SRS15', 'SRS15W', 'SRS9X']

# %%
# stock_all()

# %%
def get_weekly_demand(demand_gy4, mondays_str):
    srs_demand = demand_gy4.query('product_family.str.startswith("SRS")').copy()
    srs_demand['printed_due'] = pd.to_datetime(srs_demand['printed_due'])
    # srs_demand = srs_demand[srs_demand['printed_due'] < date.today() + timedelta(weeks=15)]
    srs_demand = srs_demand[srs_demand['printed_due'] < datetime.now() + timedelta(weeks=15)]
    srs_demand['over1000'] = srs_demand['product_length'] > 1000
    srs_demand['total_meter'] = srs_demand['product_length'] * srs_demand['qty'] / 1000
    srs_cols_to_keep = ['product_length', 'product_family', 'product_model', 'item_description', 'printed_due', 'qty', 'mos', 'over1000', 'total_meter']
    srs_demand = srs_demand[srs_cols_to_keep]
    srs_demand['demand_week'] = srs_demand['printed_due'].apply(lambda x: next(i for i in mondays_str[::-1] if i <= x))
    srs_demand['total_meter'] = srs_demand['total_meter'].astype('int')
    srs_demand_sum = srs_demand.groupby(['product_family', 'product_model', 'over1000', 'demand_week'])['total_meter'].sum()
    srs_demand_sum = srs_demand_sum.reset_index()                            
    weekly_demand = srs_demand_sum.pivot(index=['product_family', 'product_model', 'over1000'], columns='demand_week', values='total_meter')
    weekly_demand_cols = weekly_demand.columns
    for week in mondays_str:
        if week not in weekly_demand_cols:
            weekly_demand[week] = None
    weekly_demand = weekly_demand[mondays_str]
    weekly_demand = weekly_demand.fillna(0)
    weekly_demand['w14'] = weekly_demand.sum(axis=1)
    weekly_demand['w8'] = weekly_demand.iloc[:, :8].sum(axis=1)    
    return weekly_demand
    
def get_gy4_stock(stock_gy4):
    srs_stock = stock_gy4.query('family.str.contains("SRS") & length >= 1000').copy()
    for r in srs_stock.itertuples():
        index = r[0]
        if r.model.endswith("W"):
            srs_stock.loc[index, 'model'] = r.model[:-1]
            srs_stock.loc[index, 'family'] = 'SRS-W'
    stock_sum = srs_stock.groupby(['family', 'model', 'length'])['total_length'].sum()
    return stock_sum.reset_index()

def generate_gy4_demand():    
    mondays = get_mondays()
    weekly_demand = get_weekly_demand(demand.GY4, mondays)
    # mondays_str = [date.fromordinal(x.toordinal()) for x in mondays]
    # weekly_demand = get_weekly_demand(demand.GY4, mondays_str)
    gy4_stock = get_gy4_stock(stock.GY4)
    for r in weekly_demand.itertuples():
        index = r[0]
        # print(index)
        family, model, over1000 = index
        temp_demand = r.w14
        target_df = gy4_stock[(gy4_stock['family'] == family) & (gy4_stock['model'] == model)]
        if  over1000:
            temp_stock = target_df[target_df['length'] > 1000]['total_length'].sum()
        else:
            temp_stock = target_df[target_df['length'] == 1000]['total_length'].sum()
        weekly_demand.loc[index, 'gy4_stock'] = temp_stock
        
        for i, v in enumerate(r[1:16]):        
            temp_stock -= v
            if temp_stock < 0:
                weekly_demand.loc[index, 'start_due'] = mondays[i]
                # weekly_demand.loc[index, 'start_due'] = mondays_str[i]
                break
    # rename_map = {}
    # for i in mondays_str:
    #     rename_map[i] = datetime.fromordinal(i.toordinal())
    # weekly_demand = weekly_demand.rename(columns=rename_map)
    return weekly_demand
gy4_kanban = generate_gy4_demand()

# %%
kanban_df = get_kanban()
kanban_df = kanban_df.set_index('des')
has_start_due = kanban_df[kanban_df.start_due.notna()][:2]
pd.concat([has_start_due, gy4_kanban], join='outer')

# gy4_kanban
# req['input'] = inp['inp_item']
# pd.concat([req, inp], ignore_index=True, axis = 1)
# pd.concat([inp, req], axis=1, join='inner').reset_index()
# Out:
#                                in_transit  stock    gy3  2023-02-20 00:00:00  \
# HSR15-3240L HALF RAIL 3             125.0  200.0  113.0                  113
# HSR20-3020L HALF RAIL 3 BLANK         0.0    0.0   11.0                   11
# (SRS, 12, False)                      NaN    NaN    NaN                    0
# (SRS, 15, False)                      NaN    NaN    NaN                    0
# (SRS, 9X, False)                      NaN    NaN    NaN                    0
# (SRS-W, 12, False)                    NaN    NaN    NaN                    0
# (SRS-W, 12, True)                     NaN    NaN    NaN                    0
# (SRS-W, 15, False)                    NaN    NaN    NaN                    0
# (SRS-W, 9, False)                     NaN    NaN    NaN                    0
#
#                                2023-02-27 00:00:00  2023-03-06 00:00:00  \
# HSR15-3240L HALF RAIL 3                        113                  113
# HSR20-3020L HALF RAIL 3 BLANK                   11                   11
# (SRS, 12, False)                                 0                    0
# (SRS, 15, False)                                 0                    0
# (SRS, 9X, False)                                 0                    0
# (SRS-W, 12, False)                               0                    0
# (SRS-W, 12, True)                                0                    0
# (SRS-W, 15, False)                               0                    0
# (SRS-W, 9, False)                                0                    0
#
#                                2023-03-13 00:00:00  2023-03-20 00:00:00  \
# HSR15-3240L HALF RAIL 3                        113                  108
# HSR20-3020L HALF RAIL 3 BLANK                   11                   11
# (SRS, 12, False)                                 0                    0
# (SRS, 15, False)                                 0                    0
# (SRS, 9X, False)                                 0                    0
# (SRS-W, 12, False)                               0                    0
# (SRS-W, 12, True)                                0                    0
# (SRS-W, 15, False)                               0                    0
# (SRS-W, 9, False)                                0                    0
#
#                                2023-03-27 00:00:00  2023-04-03 00:00:00  ...  \
# HSR15-3240L HALF RAIL 3                      106.0                103.0  ...
# HSR20-3020L HALF RAIL 3 BLANK                 11.0                 11.0  ...
# (SRS, 12, False)                               0.0                 73.0  ...
# (SRS, 15, False)                               0.0                  0.0  ...
# (SRS, 9X, False)                               0.0                  0.0  ...
# (SRS-W, 12, False)                             0.0                  0.0  ...
# (SRS-W, 12, True)                              0.0                  0.0  ...
# (SRS-W, 15, False)                            56.0                  1.0  ...
# (SRS-W, 9, False)                              0.0                  0.0  ...
#
#                                2023-05-01 00:00:00  2023-05-08 00:00:00  \
# HSR15-3240L HALF RAIL 3                       82.0                 82.0
# HSR20-3020L HALF RAIL 3 BLANK                  2.0                  2.0
# (SRS, 12, False)                              71.0                114.0
# (SRS, 15, False)                               0.0                  0.0
# (SRS, 9X, False)                               0.0                104.0
# (SRS-W, 12, False)                             0.0                 11.0
# (SRS-W, 12, True)                              0.0                  0.0
# (SRS-W, 15, False)                            57.0                 47.0
# (SRS-W, 9, False)                              0.0                  0.0
#
#                                2023-05-15 00:00:00  2023-05-22 00:00:00  \
# HSR15-3240L HALF RAIL 3                       82.0                 52.0
# HSR20-3020L HALF RAIL 3 BLANK                  2.0                 -4.0
# (SRS, 12, False)                              41.0                 83.0
# (SRS, 15, False)                               0.0                  1.0
# (SRS, 9X, False)                              25.0                  3.0
# (SRS-W, 12, False)                            37.0                 26.0
# (SRS-W, 12, True)                              0.0                  0.0
# (SRS-W, 15, False)                            47.0                 50.0
# (SRS-W, 9, False)                              0.0                  0.0
#
#                                2023-05-29 00:00:00  2023-06-05 00:00:00  \
# HSR15-3240L HALF RAIL 3                      -16.0                -16.0
# HSR20-3020L HALF RAIL 3 BLANK                -10.0                -10.0
# (SRS, 12, False)                              57.0                217.0
# (SRS, 15, False)                               0.0                  8.0
# (SRS, 9X, False)                               0.0                 82.0
# (SRS-W, 12, False)                             6.0                 24.0
# (SRS-W, 12, True)                              0.0                  0.0
# (SRS-W, 15, False)                             1.0                 47.0
# (SRS-W, 9, False)                              0.0                  0.0
#
#                                start_due     w14     w8 gy4_stock
# HSR15-3240L HALF RAIL 3       2023-02-20     NaN    NaN       NaN
# HSR20-3020L HALF RAIL 3 BLANK 2023-05-22     NaN    NaN       NaN
# (SRS, 12, False)                     NaT  1046.0  153.0   1008.00
# (SRS, 15, False)                     NaT    25.0    0.0    297.00
# (SRS, 9X, False)              2023-05-08   214.0    0.0     39.00
# (SRS-W, 12, False)            2023-05-29   176.0   14.0    147.00
# (SRS-W, 12, True)                    NaT    15.0    4.0    213.74
# (SRS-W, 15, False)            2023-05-29   369.0   59.0    321.00
# (SRS-W, 9, False)                    NaT    16.0    1.0    678.00
#
# [9 rows x 23 columns]

# %%
# mondays_str = [x.strftime("%Y-%m-%d") for x in mondays]

# srs_demand['due_week'] = srs_demand['printed_due'].apply(lambda x: x)
# Out:
# [datetime.date(2023, 6, 5), datetime.date(2023, 5, 29), datetime.date(2023, 5, 22), datetime.date(2023, 5, 15), datetime.date(2023, 5, 8), datetime.date(2023, 5, 1), datetime.date(2023, 4, 24), datetime.date(2023, 4, 17), datetime.date(2023, 4, 10), datetime.date(2023, 4, 3), datetime.date(2023, 3, 27), datetime.date(2023, 3, 20), datetime.date(2023, 3, 13), datetime.date(2023, 3, 6), datetime.date(2023, 2, 27), datetime.date(2023, 2, 20)]
#       product_length product_family product_model    item_description  \
# 920           1189.0          SRS-W            12  SRS12W-1189LM RAIL
# 924           1177.0          SRS-W            12  SRS12W-1177LM RAIL
# 960           1110.0          SRS-W            12  SRS12W-1110LM RAIL
# 1074           945.0          SRS-W            15   SRS15W-945LM RAIL
# 1141           865.0            SRS            12    SRS12-865LM RAIL
# ...              ...            ...           ...                 ...
# 2343           110.0          SRS-W            15   SRS15W-110LM RAIL
# 2344           110.0          SRS-W            15   SRS15W-110LM RAIL
# 2345           110.0          SRS-W            15   SRS15W-110LM RAIL
# 2346           110.0          SRS-W            15   SRS15W-110LM RAIL
# 2366            82.0          SRS-W            15   SRS15W-82LPM RAIL
#
#      printed_due   qty                                                mos  \
# 920   2023-04-10   2.0                                            M185272
# 924   2023-04-10   2.0                                            M185274
# 960   2023-04-21  10.0                                   M197529, M197530
# 1074  2023-03-31  60.0  M121981, M121975, M121976, M121982, M121974, M...
# 1141  2023-04-11  16.0                                   M181615, M181616
# ...          ...   ...                                                ...
# 2343  2023-04-06   1.0                                            M197706
# 2344  2023-04-06   1.0                                            M197708
# 2345  2023-04-07   1.0                                            M197710
# 2346  2023-04-07   1.0                                            M197712
# 2366  2023-04-03  17.0                                            M166673
#
#       over1000  total_meter demand_week
# 920       True        2.378  2023-04-10
# 924       True        2.354  2023-04-10
# 960       True       11.100  2023-04-17
# 1074     False       56.700  2023-03-27
# 1141     False       13.840  2023-04-10
# ...        ...          ...         ...
# 2343     False        0.110  2023-04-03
# 2344     False        0.110  2023-04-03
# 2345     False        0.110  2023-04-03
# 2346     False        0.110  2023-04-03
# 2366     False        1.394  2023-04-03
#
# [72 rows x 10 columns]

# %%
# Out:
#                                in_transit  stock  gy3  2023-02-20 00:00:00  \
# des
# HSR15-3240L HALF RAIL 3               125    200  113                  113
# HSR20-3020L HALF RAIL 3 BLANK           0      0   11                   11
# HSR25-3001L HALF RAIL 3               100   1350   74                   74
# HSR25-4100L HALF RAIL 3                 0      0    0                    0
# HSR25-5100L HALF RAIL 3                28    210    0                    0
# HSR30-3020L HALF RAIL 3               144      0   23                   23
# HSR30-5100L HALF RAIL 3                30    230    4                    4
# HSR35-3020L HALF RAIL 3                 0    392  228                  228
# HSR35-1320L HALF RAIL 3                50    233    6                    6
# HSR35-2040L HALF RAIL 3               102    673  145                  145
# HSR35-5100L HALF RAIL 3                 0    483    1                    1
# HSR35-7000L HALF RAIL 3                 0    240    3                    3
# HSR45-3020L HALF RAIL 3                 0    602  138                  138
# HSR45-1200L HALF RAIL 3               255    621   50                   50
# HSR45-1568L HALF RAIL 3                 0      0   12                   12
# SHS15-3040L HALF RAIL 3               200    960    1                    1
# SHS15-3040L HALF RAIL 3 BLANK           0      0   84                   84
# SHS20-3001L HALF RAIL 3               325    600  131                  127
# SHS20-5020L HALF RAIL 3                24    192    0                   -1
# SHS25-4100L HALF RAIL 3                 0      0    0                    0
# SHS25-5020L HALF RAIL 3                 0      0    2                    2
# SHS25-7000L HALF RAIL 3                 8     50    1                    1
# SHS30-3020L HALF RAIL 3               266     44   90                   90
# SHS30-3220 HALF RAIL 3 BLANK          120     58  172                  172
# SHS30-1216LTS-II HALF RAIL 3          200      0   48                   48
# SHS30-4100L HALF RAIL 3                54      0    0                    0
# SHS35-3020L HALF RAIL 3               160     98    0                    0
# SHS35-3020L HALF RAIL 3 BLANK          36      0    7                    7
# SHS45-3020L HALF RAIL 3                 0    660   64                   64
# SHS45-4050L HALF RAIL 3                 0    190    0                    0
# SR15-3240L HALF RAIL 3                240   1200  206                  201
# SR15-3240LY HALF RAIL 3                25      0  236                  236
# SR20-3000L HALF RAIL 3 BLANK            0      0  360                  140
# SR25-3000LY HALF RAIL 3                 0    672  531                  511
# SR25-7000LY HALF RAIL 3                 0     10    0                    0
# HRW27-3040L HALF RAIL 3                 0    243   23                   23
# HRW35-3040L HALF RAIL 3                 0    210   58                   58
# SHW27-3040L HALF RAIL 3                 0      0  133                  133
#
#                                2023-02-27 00:00:00  2023-03-06 00:00:00  \
# des
# HSR15-3240L HALF RAIL 3                        113                  113
# HSR20-3020L HALF RAIL 3 BLANK                   11                   11
# HSR25-3001L HALF RAIL 3                         74                   74
# HSR25-4100L HALF RAIL 3                          0                    0
# HSR25-5100L HALF RAIL 3                          0                    0
# HSR30-3020L HALF RAIL 3                         23                   23
# HSR30-5100L HALF RAIL 3                          4                    4
# HSR35-3020L HALF RAIL 3                        228                  216
# HSR35-1320L HALF RAIL 3                          6                    6
# HSR35-2040L HALF RAIL 3                        145                  143
# HSR35-5100L HALF RAIL 3                          1                    1
# HSR35-7000L HALF RAIL 3                          3                    3
# HSR45-3020L HALF RAIL 3                        138                  138
# HSR45-1200L HALF RAIL 3                         50                   50
# HSR45-1568L HALF RAIL 3                         12                   12
# SHS15-3040L HALF RAIL 3                          1                    1
# SHS15-3040L HALF RAIL 3 BLANK                   84                   84
# SHS20-3001L HALF RAIL 3                        124                  124
# SHS20-5020L HALF RAIL 3                         -1                   -1
# SHS25-4100L HALF RAIL 3                          0                    0
# SHS25-5020L HALF RAIL 3                          2                    2
# SHS25-7000L HALF RAIL 3                          1                    1
# SHS30-3020L HALF RAIL 3                         90                   63
# SHS30-3220 HALF RAIL 3 BLANK                   172                  172
# SHS30-1216LTS-II HALF RAIL 3                    48                   48
# SHS30-4100L HALF RAIL 3                          0                    0
# SHS35-3020L HALF RAIL 3                          0                    0
# SHS35-3020L HALF RAIL 3 BLANK                    7                    7
# SHS45-3020L HALF RAIL 3                         64                   64
# SHS45-4050L HALF RAIL 3                          0                    0
# SR15-3240L HALF RAIL 3                         201                  201
# SR15-3240LY HALF RAIL 3                        236                  236
# SR20-3000L HALF RAIL 3 BLANK                   140                  140
# SR25-3000LY HALF RAIL 3                        499                  459
# SR25-7000LY HALF RAIL 3                          0                    0
# HRW27-3040L HALF RAIL 3                         23                   23
# HRW35-3040L HALF RAIL 3                         58                   58
# SHW27-3040L HALF RAIL 3                        133                  133
#
#                                2023-03-13 00:00:00  2023-03-20 00:00:00  \
# des
# HSR15-3240L HALF RAIL 3                        113                  108
# HSR20-3020L HALF RAIL 3 BLANK                   11                   11
# HSR25-3001L HALF RAIL 3                         74                   74
# HSR25-4100L HALF RAIL 3                          0                    0
# HSR25-5100L HALF RAIL 3                          0                    0
# HSR30-3020L HALF RAIL 3                         23                   14
# HSR30-5100L HALF RAIL 3                          4                    4
# HSR35-3020L HALF RAIL 3                        216                  213
# HSR35-1320L HALF RAIL 3                          6                    6
# HSR35-2040L HALF RAIL 3                        143                  143
# HSR35-5100L HALF RAIL 3                          1                    1
# HSR35-7000L HALF RAIL 3                          3                    3
# HSR45-3020L HALF RAIL 3                        138                  138
# HSR45-1200L HALF RAIL 3                         50                   50
# HSR45-1568L HALF RAIL 3                         12                   12
# SHS15-3040L HALF RAIL 3                         -3                   -3
# SHS15-3040L HALF RAIL 3 BLANK                   84                   84
# SHS20-3001L HALF RAIL 3                        106                  104
# SHS20-5020L HALF RAIL 3                         -1                   -1
# SHS25-4100L HALF RAIL 3                          0                    0
# SHS25-5020L HALF RAIL 3                          2                    2
# SHS25-7000L HALF RAIL 3                          1                    1
# SHS30-3020L HALF RAIL 3                         63                   63
# SHS30-3220 HALF RAIL 3 BLANK                   172                  172
# SHS30-1216LTS-II HALF RAIL 3                    48                   48
# SHS30-4100L HALF RAIL 3                          0                    0
# SHS35-3020L HALF RAIL 3                          0                  -30
# SHS35-3020L HALF RAIL 3 BLANK                    7                    7
# SHS45-3020L HALF RAIL 3                         64                   64
# SHS45-4050L HALF RAIL 3                          0                    0
# SR15-3240L HALF RAIL 3                         171                  171
# SR15-3240LY HALF RAIL 3                        236                  236
# SR20-3000L HALF RAIL 3 BLANK                   140                  140
# SR25-3000LY HALF RAIL 3                        431                  333
# SR25-7000LY HALF RAIL 3                          0                    0
# HRW27-3040L HALF RAIL 3                         23                   23
# HRW35-3040L HALF RAIL 3                         58                   58
# SHW27-3040L HALF RAIL 3                        133                  133
#
#                                2023-03-27 00:00:00  2023-04-03 00:00:00  \
# des
# HSR15-3240L HALF RAIL 3                        106                  103
# HSR20-3020L HALF RAIL 3 BLANK                   11                   11
# HSR25-3001L HALF RAIL 3                         69                   69
# HSR25-4100L HALF RAIL 3                          0                    0
# HSR25-5100L HALF RAIL 3                          0                    0
# HSR30-3020L HALF RAIL 3                         14                   11
# HSR30-5100L HALF RAIL 3                        -18                  -18
# HSR35-3020L HALF RAIL 3                        208                  208
# HSR35-1320L HALF RAIL 3                          6                    6
# HSR35-2040L HALF RAIL 3                        143                  143
# HSR35-5100L HALF RAIL 3                          1                    1
# HSR35-7000L HALF RAIL 3                          3                    3
# HSR45-3020L HALF RAIL 3                        138                  136
# HSR45-1200L HALF RAIL 3                         50                   50
# HSR45-1568L HALF RAIL 3                         12                   12
# SHS15-3040L HALF RAIL 3                         -3                  -15
# SHS15-3040L HALF RAIL 3 BLANK                   84                   84
# SHS20-3001L HALF RAIL 3                         95                   78
# SHS20-5020L HALF RAIL 3                         -1                   -1
# SHS25-4100L HALF RAIL 3                          0                    0
# SHS25-5020L HALF RAIL 3                          2                    2
# SHS25-7000L HALF RAIL 3                          1                    1
# SHS30-3020L HALF RAIL 3                         61                   61
# SHS30-3220 HALF RAIL 3 BLANK                    77                   77
# SHS30-1216LTS-II HALF RAIL 3                    48                   48
# SHS30-4100L HALF RAIL 3                          0                  -10
# SHS35-3020L HALF RAIL 3                        -73                  -96
# SHS35-3020L HALF RAIL 3 BLANK                    7                    7
# SHS45-3020L HALF RAIL 3                         56                   53
# SHS45-4050L HALF RAIL 3                          0                    0
# SR15-3240L HALF RAIL 3                         153                  141
# SR15-3240LY HALF RAIL 3                        236                  236
# SR20-3000L HALF RAIL 3 BLANK                    50                   50
# SR25-3000LY HALF RAIL 3                        185                  183
# SR25-7000LY HALF RAIL 3                          0                    0
# HRW27-3040L HALF RAIL 3                         21                   21
# HRW35-3040L HALF RAIL 3                         58                   54
# SHW27-3040L HALF RAIL 3                        131                  131
#
#                                2023-04-10 00:00:00  2023-04-17 00:00:00  \
# des
# HSR15-3240L HALF RAIL 3                        103                   89
# HSR20-3020L HALF RAIL 3 BLANK                   11                    2
# HSR25-3001L HALF RAIL 3                         67                   67
# HSR25-4100L HALF RAIL 3                          0                   -6
# HSR25-5100L HALF RAIL 3                          0                    0
# HSR30-3020L HALF RAIL 3                        -65                 -108
# HSR30-5100L HALF RAIL 3                        -18                  -18
# HSR35-3020L HALF RAIL 3                        208                  198
# HSR35-1320L HALF RAIL 3                          6                    6
# HSR35-2040L HALF RAIL 3                        143                  143
# HSR35-5100L HALF RAIL 3                          1                    1
# HSR35-7000L HALF RAIL 3                          3                    3
# HSR45-3020L HALF RAIL 3                        136                  136
# HSR45-1200L HALF RAIL 3                         50                   50
# HSR45-1568L HALF RAIL 3                         12                   12
# SHS15-3040L HALF RAIL 3                        -22                  -26
# SHS15-3040L HALF RAIL 3 BLANK                   84                   84
# SHS20-3001L HALF RAIL 3                         43                   29
# SHS20-5020L HALF RAIL 3                         -1                   -1
# SHS25-4100L HALF RAIL 3                          0                    0
# SHS25-5020L HALF RAIL 3                          2                    2
# SHS25-7000L HALF RAIL 3                          1                    1
# SHS30-3020L HALF RAIL 3                         61                   -8
# SHS30-3220 HALF RAIL 3 BLANK                    77                   77
# SHS30-1216LTS-II HALF RAIL 3                    48                   48
# SHS30-4100L HALF RAIL 3                        -10                  -52
# SHS35-3020L HALF RAIL 3                       -188                 -278
# SHS35-3020L HALF RAIL 3 BLANK                    7                    7
# SHS45-3020L HALF RAIL 3                         50                   47
# SHS45-4050L HALF RAIL 3                          0                    0
# SR15-3240L HALF RAIL 3                         101                   77
# SR15-3240LY HALF RAIL 3                        180                  173
# SR20-3000L HALF RAIL 3 BLANK                    50                   50
# SR25-3000LY HALF RAIL 3                         86                   -4
# SR25-7000LY HALF RAIL 3                          0                    0
# HRW27-3040L HALF RAIL 3                         18                   18
# HRW35-3040L HALF RAIL 3                         51                   47
# SHW27-3040L HALF RAIL 3                        102                 -106
#
#                                2023-04-24 00:00:00  2023-05-01 00:00:00  \
# des
# HSR15-3240L HALF RAIL 3                         82                   82
# HSR20-3020L HALF RAIL 3 BLANK                    2                    2
# HSR25-3001L HALF RAIL 3                         54                   54
# HSR25-4100L HALF RAIL 3                         -6                  -20
# HSR25-5100L HALF RAIL 3                          0                    0
# HSR30-3020L HALF RAIL 3                       -129                 -129
# HSR30-5100L HALF RAIL 3                        -30                  -30
# HSR35-3020L HALF RAIL 3                        191                  153
# HSR35-1320L HALF RAIL 3                          6                    6
# HSR35-2040L HALF RAIL 3                        143                  143
# HSR35-5100L HALF RAIL 3                         -1                   -1
# HSR35-7000L HALF RAIL 3                          3                    3
# HSR45-3020L HALF RAIL 3                        130                  130
# HSR45-1200L HALF RAIL 3                         50                   50
# HSR45-1568L HALF RAIL 3                         12                   12
# SHS15-3040L HALF RAIL 3                        -28                  -30
# SHS15-3040L HALF RAIL 3 BLANK                   82                   82
# SHS20-3001L HALF RAIL 3                        -19                  -46
# SHS20-5020L HALF RAIL 3                         -1                   -1
# SHS25-4100L HALF RAIL 3                          0                    0
# SHS25-5020L HALF RAIL 3                          2                   -8
# SHS25-7000L HALF RAIL 3                          1                    1
# SHS30-3020L HALF RAIL 3                        -11                  -38
# SHS30-3220 HALF RAIL 3 BLANK                    77                   77
# SHS30-1216LTS-II HALF RAIL 3                    48                   48
# SHS30-4100L HALF RAIL 3                        -52                  -52
# SHS35-3020L HALF RAIL 3                       -339                 -434
# SHS35-3020L HALF RAIL 3 BLANK                    7                    7
# SHS45-3020L HALF RAIL 3                         -7                  -14
# SHS45-4050L HALF RAIL 3                          0                    0
# SR15-3240L HALF RAIL 3                        -100                 -100
# SR15-3240LY HALF RAIL 3                        165                  165
# SR20-3000L HALF RAIL 3 BLANK                   -39                  -42
# SR25-3000LY HALF RAIL 3                        -54                  -56
# SR25-7000LY HALF RAIL 3                          0                    0
# HRW27-3040L HALF RAIL 3                         -2                   -6
# HRW35-3040L HALF RAIL 3                         10                   10
# SHW27-3040L HALF RAIL 3                       -138                 -138
#
#                                2023-05-08 00:00:00  2023-05-15 00:00:00  \
# des
# HSR15-3240L HALF RAIL 3                         82                   82
# HSR20-3020L HALF RAIL 3 BLANK                    2                    2
# HSR25-3001L HALF RAIL 3                         54                   46
# HSR25-4100L HALF RAIL 3                        -20                  -22
# HSR25-5100L HALF RAIL 3                         -8                  -26
# HSR30-3020L HALF RAIL 3                       -159                 -204
# HSR30-5100L HALF RAIL 3                        -30                  -30
# HSR35-3020L HALF RAIL 3                        126                   49
# HSR35-1320L HALF RAIL 3                          6                    6
# HSR35-2040L HALF RAIL 3                        143                  143
# HSR35-5100L HALF RAIL 3                         -1                   -1
# HSR35-7000L HALF RAIL 3                          3                    3
# HSR45-3020L HALF RAIL 3                        127                   93
# HSR45-1200L HALF RAIL 3                         50                  -86
# HSR45-1568L HALF RAIL 3                         12                   12
# SHS15-3040L HALF RAIL 3                        -39                  -51
# SHS15-3040L HALF RAIL 3 BLANK                   82                   68
# SHS20-3001L HALF RAIL 3                       -126                 -152
# SHS20-5020L HALF RAIL 3                         -1                   -1
# SHS25-4100L HALF RAIL 3                          0                   -4
# SHS25-5020L HALF RAIL 3                         -8                   -8
# SHS25-7000L HALF RAIL 3                          1                    1
# SHS30-3020L HALF RAIL 3                        -49                 -161
# SHS30-3220 HALF RAIL 3 BLANK                    77                   77
# SHS30-1216LTS-II HALF RAIL 3                    48                   48
# SHS30-4100L HALF RAIL 3                        -52                  -95
# SHS35-3020L HALF RAIL 3                       -515                 -572
# SHS35-3020L HALF RAIL 3 BLANK                    7                    7
# SHS45-3020L HALF RAIL 3                        -32                  -66
# SHS45-4050L HALF RAIL 3                        -22                  -22
# SR15-3240L HALF RAIL 3                        -106                 -208
# SR15-3240LY HALF RAIL 3                        149                   91
# SR20-3000L HALF RAIL 3 BLANK                   -46                  -51
# SR25-3000LY HALF RAIL 3                       -146                 -158
# SR25-7000LY HALF RAIL 3                          0                   -6
# HRW27-3040L HALF RAIL 3                         -6                   -6
# HRW35-3040L HALF RAIL 3                         10                   10
# SHW27-3040L HALF RAIL 3                       -141                 -141
#
#                                2023-05-22 00:00:00  2023-05-29 00:00:00  \
# des
# HSR15-3240L HALF RAIL 3                         52                  -16
# HSR20-3020L HALF RAIL 3 BLANK                   -4                  -10
# HSR25-3001L HALF RAIL 3                          0                    0
# HSR25-4100L HALF RAIL 3                        -24                  -52
# HSR25-5100L HALF RAIL 3                        -30                  -48
# HSR30-3020L HALF RAIL 3                       -314                 -363
# HSR30-5100L HALF RAIL 3                        -30                  -30
# HSR35-3020L HALF RAIL 3                        -21                  -85
# HSR35-1320L HALF RAIL 3                          6                    6
# HSR35-2040L HALF RAIL 3                        143                   77
# HSR35-5100L HALF RAIL 3                         -9                   -9
# HSR35-7000L HALF RAIL 3                          3                   -3
# HSR45-3020L HALF RAIL 3                         37                   -1
# HSR45-1200L HALF RAIL 3                       -188                 -188
# HSR45-1568L HALF RAIL 3                         12                  -40
# SHS15-3040L HALF RAIL 3                       -108                 -108
# SHS15-3040L HALF RAIL 3 BLANK                   -1                   -1
# SHS20-3001L HALF RAIL 3                       -331                 -340
# SHS20-5020L HALF RAIL 3                         -1                   -1
# SHS25-4100L HALF RAIL 3                         -4                   -4
# SHS25-5020L HALF RAIL 3                         -8                  -18
# SHS25-7000L HALF RAIL 3                          1                    1
# SHS30-3020L HALF RAIL 3                       -324                 -337
# SHS30-3220 HALF RAIL 3 BLANK                    77                   77
# SHS30-1216LTS-II HALF RAIL 3                    48                   48
# SHS30-4100L HALF RAIL 3                        -95                  -95
# SHS35-3020L HALF RAIL 3                       -664                 -689
# SHS35-3020L HALF RAIL 3 BLANK                    7                    7
# SHS45-3020L HALF RAIL 3                        -73                 -115
# SHS45-4050L HALF RAIL 3                        -22                  -22
# SR15-3240L HALF RAIL 3                        -222                 -504
# SR15-3240LY HALF RAIL 3                         81                   24
# SR20-3000L HALF RAIL 3 BLANK                   -51                  -51
# SR25-3000LY HALF RAIL 3                       -282                 -285
# SR25-7000LY HALF RAIL 3                         -6                   -6
# HRW27-3040L HALF RAIL 3                         -6                  -19
# HRW35-3040L HALF RAIL 3                          8                  -18
# SHW27-3040L HALF RAIL 3                       -199                 -206
#
#                                2023-06-05 00:00:00  start_due
# des
# HSR15-3240L HALF RAIL 3                        -16 2023-02-20
# HSR20-3020L HALF RAIL 3 BLANK                  -10 2023-05-22
# HSR25-3001L HALF RAIL 3                         -2 2023-02-20
# HSR25-4100L HALF RAIL 3                        -56 2023-04-17
# HSR25-5100L HALF RAIL 3                        -48 2023-02-20
# HSR30-3020L HALF RAIL 3                       -370 2023-02-20
# HSR30-5100L HALF RAIL 3                        -30 2023-02-20
# HSR35-3020L HALF RAIL 3                        -97 2023-05-22
# HSR35-1320L HALF RAIL 3                          6 2023-02-20
# HSR35-2040L HALF RAIL 3                        -55 2023-05-29
# HSR35-5100L HALF RAIL 3                         -9 2023-04-24
# HSR35-7000L HALF RAIL 3                         -3 2023-05-29
# HSR45-3020L HALF RAIL 3                         -4 2023-05-29
# HSR45-1200L HALF RAIL 3                       -188 2023-02-20
# HSR45-1568L HALF RAIL 3                        -66 2023-05-29
# SHS15-3040L HALF RAIL 3                       -110 2023-02-20
# SHS15-3040L HALF RAIL 3 BLANK                   -6 2023-05-22
# SHS20-3001L HALF RAIL 3                       -369 2023-02-20
# SHS20-5020L HALF RAIL 3                         -1 2023-02-20
# SHS25-4100L HALF RAIL 3                         -4 2023-05-15
# SHS25-5020L HALF RAIL 3                        -18 2023-05-01
# SHS25-7000L HALF RAIL 3                          1 2023-02-20
# SHS30-3020L HALF RAIL 3                       -339 2023-02-20
# SHS30-3220 HALF RAIL 3 BLANK                    77 2023-03-27
# SHS30-1216LTS-II HALF RAIL 3                    48 2023-02-20
# SHS30-4100L HALF RAIL 3                        -95 2023-02-20
# SHS35-3020L HALF RAIL 3                       -735 2023-02-20
# SHS35-3020L HALF RAIL 3 BLANK                    7 2023-02-20
# SHS45-3020L HALF RAIL 3                       -124 2023-04-24
# SHS45-4050L HALF RAIL 3                        -40 2023-05-08
# SR15-3240L HALF RAIL 3                        -518 2023-02-20
# SR15-3240LY HALF RAIL 3                        -28 2023-05-29
# SR20-3000L HALF RAIL 3 BLANK                   -51 2023-04-24
# SR25-3000LY HALF RAIL 3                       -303 2023-04-17
# SR25-7000LY HALF RAIL 3                         -6 2023-05-15
# HRW27-3040L HALF RAIL 3                        -19 2023-04-24
# HRW35-3040L HALF RAIL 3                        -18 2023-05-29
# SHW27-3040L HALF RAIL 3                       -208 2023-04-17

# %%
reversed_mondays

# %%
mondays_str[::-1]
# Out:
# ['2023-02-20',
#  '2023-02-27',
#  '2023-03-06',
#  '2023-03-13',
#  '2023-03-20',
#  '2023-03-27',
#  '2023-04-03',
#  '2023-04-10',
#  '2023-04-17',
#  '2023-04-24',
#  '2023-05-01',
#  '2023-05-08',
#  '2023-05-15',
#  '2023-05-22',
#  '2023-05-29',
#  '2023-06-05']
