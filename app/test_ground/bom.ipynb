# %%
import pandas as pd

bom = pd.read_parquet('bom.parquet')
# bom = bom[(bom['type'] == 'LG') & (bom.reference_number.str.contains('GYHAAS')) & bom['finish_item'].str.contains('RAIL') & bom['componemt_item'].str.contains('RAIL')]

# bom_g = bom.groupby(['finish_item', 'componemt_item']).first()

# %%
target = bom[(bom['type'] == 'LG') & (bom['finish_item'].str.contains('HSR30') & bom['finish_item'].str.contains('BLOCK') & bom['component_item'].str.contains('BLOCK') )]

# %%
target[target['finish_item'] == 'HSR30C HALF BLOCK 2']
# Out:
#       type reference_number order_number finish_item_number  \
# 62542   LG              GY2      M067403    401130100002002
# 62543   LG              GY2      M067404    401130100002002
# 62544   LG              GY2      M067405    401130100002002
# 62545   LG              GY2      M067406    401130100002002
# 62546   LG              GY2      M067407    401130100002002
# ...    ...              ...          ...                ...
# 46      LG              GY2      M201462    401130100002002
# 98      LG              GY2      M201443    401130100002002
# 99      LG              GY2      M201443    401130100002002
# 100     LG              GY2      M201465    401130100002002
# 101     LG              GY2      M201465    401130100002002
#
#                finish_item   qty  order_status component_item_number  \
# 62542  HSR30C HALF BLOCK 2  43.0          55.0       Z02001130036000
# 62543  HSR30C HALF BLOCK 2  43.0          55.0       Z02001130036000
# ...
